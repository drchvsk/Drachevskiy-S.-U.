# %%
i=1
while i<=100:
    if i%3==0
        if i%5==0:
            print('FizzBuzz')
        else:
            print('Fizz')
    elif i%5==0:
        print('Buzz')
    else:
        print(i)
    i+=1

# %%
a=0
b=1
i=2
while i<100:
    c=a+b
    a=b
    b=c
    i+=1
print(c)
# Out:
# 218922995834555169026

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

lag = 0.01
x = np.arange(0, np.pi, lag)
y1 = np.cos(x)
y2 = np.log(x+1)
y3 = x**(1/2)
plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)

plt.ylabel('ololol')
plt.xlabel('alalal')

plt.grid(True)
plt.show()

pwd = os.getcwd()
os.chdir('./%s' % 'png')
plt.savefig('%s.%s' % ('pic_1_5_1.pdf', fmt), 'png')
os.chdir(pwd)
